# %%
#Questão 1

#a)


def contaroco(lista, n):
    if lista==[]:
        return 0
    else:   
        if lista[0] == n:
            return 1 + contaroco(lista[1:], n)
        else:
            return contaroco(lista[1:], n)


print(contaroco([1,1,1,3,2,4,2], 1))


#b)


def disjuntas(lista1, lista2):
    condi=True
    if lista1==[]:  
        return condi
    else:
        if lista1[0] in lista2:
            condi=False
            return condi
    return disjuntas(lista1[1:], lista2)
    

print(disjuntas([1,2,4],[5,8,7]))


#c)


        
def merge(lista1, lista2):
    if lista1 == []:
        return lista2
    else:
        if lista1[0] <= lista2[0]:
            return [lista1[0]] + merge(lista1[1:], lista2)
        else:
            return [lista2[0]] + merge(lista1, lista2[1:])



print(merge([1,2,7],[5,7,8]))

# %%
#Questão 2


#a)

def splitLista(lista,div):
    return ([x for x in lista if x%div==0],[x for x in lista if x%div!=0])

print(splitLista([1,2,3,4,5], 2))

#b)



#c)


def max2prod(lista):
    maior=lista[0]
    maior2=lista[1]
    for x in lista:
        if x>maior:
            maior2=maior
            maior=x  
        else:
            if x>maior2:
                maior2=x
    print(maior*maior2)
    

max2prod([1,40,5,9,2])


#d)

# %%
#Questão 3 

hospital = [
(
"Unidade de Cardiologia",
[ (1, "Dr. João"), (2, "Dra. Maria")],
[(101, False), (102, True), (103, False), (104, False)]
),
(
"Unidade de Pediatria",
[ (3, "Dr. Pedro"), (4, "Dra. Clara") ],
[ (201, True), (202, True), (203, True)]
)
]

#a)

def listarunidades(hospital):
    for x in hospital:
        print(x[0])


listarunidades(hospital)

#b)

def dispocamas(hospital):
    cont=0
    for x in hospital:
        for h in x[2]:
            if h[1]==False:
                cont=cont+1
    return cont

dispocamas(hospital) #3

#c)

def listarmedicos(hospital,un):
    for x in hospital:
        if x[0]==un:
            return x[1]
        
    

listarmedicos(hospital,"Unidade de Cardiologia")

#d)

def vermedico(hopsital,un,med):
    condi=False
    for x in hospital:
        if x[0]==un:
            for h in x[1]:
                if med in h[1]:
                    condi=True
    return condi

vermedico(hospital,"Unidade de Cardiologia","Dra. Maria")

#e)

def adicionarmed(hospital,un,med):
